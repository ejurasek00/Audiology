# %% [markdown]
# GPT-5

# %% [markdown]
# L1

# %%
# Comparator.py

from collections import Counter


def parse_custom_set(input_list):
    # Convert a list of sets into a list of sorted tuples
    return [tuple(sorted(s)) for s in input_list]


def compare_sets(set1, set_gold):
    # Parse the sets
    set1_converted = parse_custom_set(set1)
    set_gold_converted = parse_custom_set(set_gold)

    # Count the occurrences of each set in set1
    set1_counter = Counter(set1_converted)

    # Convert list to set for comparison
    set1_converted_set = set(set1_converted)
    set_gold_converted_set = set(set_gold_converted)

    # Compute the intersection
    intersection = set1_converted_set.intersection(set_gold_converted_set)

    # Find hallucinations (in set1 but not in set_gold)
    hallucinations = set1_converted_set.difference(set_gold_converted_set)

    # Find missing (in set_gold but not in set1)
    missing = set_gold_converted_set.difference(set1_converted_set)

    # Print the intersection
    print("Intersection:")
    for s in intersection:
        print(s)

    # Print hallucinations
    if hallucinations:
        print("\nHallucinations:")
        for hallucination in hallucinations:
            print(hallucination)
    else:
        print("\nNo Hallucinations")

    # Print missing
    if missing:
        print("\nMissing:")
        for miss in missing:
            print(miss)
    else:
        print("\nNo Missing")

    # Print duplicates
    duplicates = [item for item, count in set1_counter.items() if count > 1]
    if duplicates:
        print("\nDuplicates in set1:")
        for duplicate in duplicates:
            print(f"{duplicate} occurs {set1_counter[duplicate]} times")
    else:
        print("\nNo Duplicates in set1")


# Compare sets
set1 = [{"SandyBrown"}, {"Gold"}, {"Prague"}, {"QR1777"}, {"Yuzu"}, {"Pecorino-Romano"}, {"Asiago"}, {"Mozzarella"}, {"Gorgonzola"}, {"Platypus"}, {"Bossa-Nova"}]
set_gold = [{"1"}	,
{"Gold"}	,
{"Asiago"}	,
{"QR1777"},	
{"Gorgonzola"}	,
{"SandyBrown"},	
{"Berlin"}	,
{"Pecorino-Romano"}	,
{"Ricotta"}	,
{"Prague"},	
{"Yuzu"}	,
{"81"}	,
{"Caprino"}	,
{"Mozzarella"}	,
{"Platypus"}	,
{"Bossa-Nova"}	,
{"Bagoss"}	]
compare_sets(set1, set_gold)

"""
# Example usage:

# Compare sets
set1 = [{"1", "2", "3"},{"2","3","1"},{"7", "8", "9"}, ]
set_gold = [{"3", "2", "1"}, {"6", "5", "4"}]
compare_sets(set1, set_gold)
"""
# Out:
# Intersection:
# ('Prague',)
# ('Mozzarella',)
# ('Gorgonzola',)
# ('SandyBrown',)
# ('Pecorino-Romano',)
# ('Yuzu',)
# ('QR1777',)
# ('Asiago',)
# ('Bossa-Nova',)
# ('Platypus',)
# ('Gold',)
#
# No Hallucinations
#
# Missing:
# ('Bagoss',)
# ('Ricotta',)
# ('Berlin',)
# ('1',)
# ('Caprino',)
# ('81',)
#
# No Duplicates in set1
# '\n# Example usage:\n\n# Compare sets\nset1 = [{"1", "2", "3"},{"2","3","1"},{"7", "8", "9"}, ]\nset_gold = [{"3", "2", "1"}, {"6", "5", "4"}]\ncompare_sets(set1, set_gold)\n'

# %% [markdown]
# L2

# %%
# Comparator.py

from collections import Counter


def parse_custom_set(input_list):
    # Convert a list of sets into a list of sorted tuples
    return [tuple(sorted(s)) for s in input_list]


def compare_sets(set1, set_gold):
    # Parse the sets
    set1_converted = parse_custom_set(set1)
    set_gold_converted = parse_custom_set(set_gold)

    # Count the occurrences of each set in set1
    set1_counter = Counter(set1_converted)

    # Convert list to set for comparison
    set1_converted_set = set(set1_converted)
    set_gold_converted_set = set(set_gold_converted)

    # Compute the intersection
    intersection = set1_converted_set.intersection(set_gold_converted_set)

    # Find hallucinations (in set1 but not in set_gold)
    hallucinations = set1_converted_set.difference(set_gold_converted_set)

    # Find missing (in set_gold but not in set1)
    missing = set_gold_converted_set.difference(set1_converted_set)

    # Print the intersection
    print("Intersection:")
    for s in intersection:
        print(s)

    # Print hallucinations
    if hallucinations:
        print("\nHallucinations:")
        for hallucination in hallucinations:
            print(hallucination)
    else:
        print("\nNo Hallucinations")

    # Print missing
    if missing:
        print("\nMissing:")
        for miss in missing:
            print(miss)
    else:
        print("\nNo Missing")

    # Print duplicates
    duplicates = [item for item, count in set1_counter.items() if count > 1]
    if duplicates:
        print("\nDuplicates in set1:")
        for duplicate in duplicates:
            print(f"{duplicate} occurs {set1_counter[duplicate]} times")
    else:
        print("\nNo Duplicates in set1")


# Compare sets
set1 = [{"SandyBrown","Prague"},{"SandyBrown","QR1777"},{"SandyBrown","Yuzu"},{"Prague","QR1777"},{"Prague","Yuzu"},{"QR1777","Yuzu"},{"Pecorino-Romano","Platypus"},{"Pecorino-Romano","Bossa-Nova"},{"Platypus","Bossa-Nova"}]
set_gold = [{"QR1777", "SandyBrown"},
{"Pecorino-Romano", "QR1777"},
{"Prague", "QR1777"},
{"QR1777", "Yuzu"},
{"81", "QR1777"},
{"Platypus", "QR1777"},
{"Bossa-Nova", "QR1777"},
{"Pecorino-Romano", "SandyBrown"},
{"Prague", "SandyBrown"},
{"SandyBrown", "Yuzu"},
{"81", "SandyBrown"},
{"Platypus", "SandyBrown"},
{"Bossa-Nova", "SandyBrown"},
{"Pecorino-Romano", "Prague"},
{"Pecorino-Romano", "Yuzu"},
{"81", "Pecorino-Romano"},
{"Pecorino-Romano", "Platypus"},
{"Bossa-Nova", "Pecorino-Romano"},
{"Prague", "Yuzu"},
{"81", "Prague"},
{"Platypus", "Prague"},
{"Bossa-Nova", "Prague"},
{"81", "Yuzu"},
{"Platypus", "Yuzu"},
{"Bossa-Nova", "Yuzu"},
{"81", "Platypus"},
{"81", "Bossa-Nova"},
{"Bossa-Nova", "Platypus"}]
compare_sets(set1, set_gold)

"""
# Example usage:

# Compare sets
set1 = [{"1", "2", "3"},{"2","3","1"},{"7", "8", "9"}, ]
set_gold = [{"3", "2", "1"}, {"6", "5", "4"}]
compare_sets(set1, set_gold)
"""
# Out:
# Intersection:
# ('Prague', 'QR1777')
# ('Prague', 'SandyBrown')
# ('SandyBrown', 'Yuzu')
# ('Bossa-Nova', 'Pecorino-Romano')
# ('QR1777', 'Yuzu')
# ('Pecorino-Romano', 'Platypus')
# ('QR1777', 'SandyBrown')
# ('Prague', 'Yuzu')
# ('Bossa-Nova', 'Platypus')
#
# No Hallucinations
#
# Missing:
# ('Platypus', 'Yuzu')
# ('Pecorino-Romano', 'QR1777')
# ('81', 'SandyBrown')
# ('81', 'Bossa-Nova')
# ('Bossa-Nova', 'Prague')
# ('Platypus', 'QR1777')
# ('81', 'Pecorino-Romano')
# ('Bossa-Nova', 'Yuzu')
# ('Pecorino-Romano', 'SandyBrown')
# ('81', 'Platypus')
# ('81', 'Prague')
# ('81', 'Yuzu')
# ('Platypus', 'SandyBrown')
# ('Bossa-Nova', 'QR1777')
# ('Pecorino-Romano', 'Prague')
# ('Pecorino-Romano', 'Yuzu')
# ('81', 'QR1777')
# ('Bossa-Nova', 'SandyBrown')
# ('Platypus', 'Prague')
#
# No Duplicates in set1
# '\n# Example usage:\n\n# Compare sets\nset1 = [{"1", "2", "3"},{"2","3","1"},{"7", "8", "9"}, ]\nset_gold = [{"3", "2", "1"}, {"6", "5", "4"}]\ncompare_sets(set1, set_gold)\n'

# %% [markdown]
# L3

# %%
# Comparator.py

from collections import Counter


def parse_custom_set(input_list):
    # Convert a list of sets into a list of sorted tuples
    return [tuple(sorted(s)) for s in input_list]


def compare_sets(set1, set_gold):
    # Parse the sets
    set1_converted = parse_custom_set(set1)
    set_gold_converted = parse_custom_set(set_gold)

    # Count the occurrences of each set in set1
    set1_counter = Counter(set1_converted)

    # Convert list to set for comparison
    set1_converted_set = set(set1_converted)
    set_gold_converted_set = set(set_gold_converted)

    # Compute the intersection
    intersection = set1_converted_set.intersection(set_gold_converted_set)

    # Find hallucinations (in set1 but not in set_gold)
    hallucinations = set1_converted_set.difference(set_gold_converted_set)

    # Find missing (in set_gold but not in set1)
    missing = set_gold_converted_set.difference(set1_converted_set)

    # Print the intersection
    print("Intersection:")
    for s in intersection:
        print(s)

    # Print hallucinations
    if hallucinations:
        print("\nHallucinations:")
        for hallucination in hallucinations:
            print(hallucination)
    else:
        print("\nNo Hallucinations")

    # Print missing
    if missing:
        print("\nMissing:")
        for miss in missing:
            print(miss)
    else:
        print("\nNo Missing")

    # Print duplicates
    duplicates = [item for item, count in set1_counter.items() if count > 1]
    if duplicates:
        print("\nDuplicates in set1:")
        for duplicate in duplicates:
            print(f"{duplicate} occurs {set1_counter[duplicate]} times")
    else:
        print("\nNo Duplicates in set1")


# Compare sets
set1 = [{"SandyBrown","Prague","QR1777"},{"SandyBrown","Prague","Yuzu"},{"SandyBrown","QR1777","Yuzu"},{"Prague","QR1777","Yuzu"},{"Pecorino-Romano","Platypus","Bossa-Nova"}]
set_gold = [{"QR1777","SandyBrown","Yuzu"},
{"Pecorino-Romano","QR1777","SandyBrown"},
{"Pecorino-Romano","Prague","QR1777"},
{"Pecorino-Romano","QR1777","Yuzu"},
{"Pecorino-Romano","Platypus","QR1777"},
{"Prague","QR1777","SandyBrown"},
{"Prague","QR1777","Yuzu"},
{"81","QR1777","SandyBrown"},
{"81","Pecorino-Romano","QR1777"},
{"81","Prague","QR1777"},
{"81","QR1777","Yuzu"},
{"81","Platypus","QR1777"},
{"81","Bossa-Nova","QR1777"},
{"Platypus","QR1777","SandyBrown"},
{"Platypus","Prague","QR1777"},
{"Platypus","QR1777","Yuzu"},
{"Bossa-Nova","QR1777","SandyBrown"},
{"Bossa-Nova","Pecorino-Romano","QR1777"},
{"Bossa-Nova","Prague","QR1777"},
{"Bossa-Nova","QR1777","Yuzu"},
{"Bossa-Nova","Platypus","QR1777"},
{"Pecorino-Romano","Prague","SandyBrown"},
{"Pecorino-Romano","SandyBrown","Yuzu"},
{"Pecorino-Romano","Platypus","SandyBrown"},
{"Prague","SandyBrown","Yuzu"},
{"81","Pecorino-Romano","SandyBrown"},
{"81","Prague","SandyBrown"},
{"81","SandyBrown","Yuzu"},
{"81","Platypus","SandyBrown"},
{"81","Bossa-Nova","SandyBrown"},
{"Platypus","Prague","SandyBrown"},
{"Platypus","SandyBrown","Yuzu"},
{"Bossa-Nova","Pecorino-Romano","SandyBrown"},
{"Bossa-Nova","Prague","SandyBrown"},
{"Bossa-Nova","SandyBrown","Yuzu"},
{"Bossa-Nova","Platypus","SandyBrown"},
{"Pecorino-Romano","Prague","Yuzu"},
{"Pecorino-Romano","Platypus","Prague"},
{"Pecorino-Romano","Platypus","Yuzu"},
{"81","Pecorino-Romano","Prague"},
{"81","Pecorino-Romano","Yuzu"},
{"81","Pecorino-Romano","Platypus"},
{"81","Bossa-Nova","Pecorino-Romano"},
{"Bossa-Nova","Pecorino-Romano","Prague"},
{"Bossa-Nova","Pecorino-Romano","Yuzu"},
{"Bossa-Nova","Pecorino-Romano","Platypus"},
{"81","Prague","Yuzu"},
{"81","Platypus","Prague"},
{"81","Bossa-Nova","Prague"},
{"Platypus","Prague","Yuzu"},
{"Bossa-Nova","Prague","Yuzu"},
{"Bossa-Nova","Platypus","Prague"},
{"81","Platypus","Yuzu"},
{"81","Bossa-Nova","Yuzu"},
{"Bossa-Nova","Platypus","Yuzu"},
{"81","Bossa-Nova","Platypus"}]
compare_sets(set1, set_gold)

"""
# Example usage:

# Compare sets
set1 = [{"1", "2", "3"},{"2","3","1"},{"7", "8", "9"}, ]
set_gold = [{"3", "2", "1"}, {"6", "5", "4"}]
compare_sets(set1, set_gold)
"""
# Out:
# Intersection:
# ('QR1777', 'SandyBrown', 'Yuzu')
# ('Prague', 'SandyBrown', 'Yuzu')
# ('Prague', 'QR1777', 'Yuzu')
# ('Bossa-Nova', 'Pecorino-Romano', 'Platypus')
# ('Prague', 'QR1777', 'SandyBrown')
#
# No Hallucinations
#
# Missing:
# ('81', 'Bossa-Nova', 'SandyBrown')
# ('81', 'Pecorino-Romano', 'Yuzu')
# ('Pecorino-Romano', 'Platypus', 'QR1777')
# ('Platypus', 'SandyBrown', 'Yuzu')
# ('Bossa-Nova', 'Pecorino-Romano', 'Prague')
# ('Pecorino-Romano', 'SandyBrown', 'Yuzu')
# ('Bossa-Nova', 'Pecorino-Romano', 'Yuzu')
# ('Bossa-Nova', 'Platypus', 'Prague')
# ('81', 'Bossa-Nova', 'Pecorino-Romano')
# ('81', 'Pecorino-Romano', 'Prague')
# ('Platypus', 'QR1777', 'Yuzu')
# ('Bossa-Nova', 'Platypus', 'Yuzu')
# ('81', 'Prague', 'SandyBrown')
# ('81', 'Platypus', 'QR1777')
# ('81', 'Bossa-Nova', 'Platypus')
# ('Bossa-Nova', 'Prague', 'SandyBrown')
# ('Pecorino-Romano', 'Prague', 'Yuzu')
# ('81', 'QR1777', 'Yuzu')
# ('81', 'Pecorino-Romano', 'QR1777')
# ('Bossa-Nova', 'QR1777', 'Yuzu')
# ...

# %% [markdown]
# L4

# %%
# Comparator.py

from collections import Counter


def parse_custom_set(input_list):
    # Convert a list of sets into a list of sorted tuples
    return [tuple(sorted(s)) for s in input_list]


def compare_sets(set1, set_gold):
    # Parse the sets
    set1_converted = parse_custom_set(set1)
    set_gold_converted = parse_custom_set(set_gold)

    # Count the occurrences of each set in set1
    set1_counter = Counter(set1_converted)

    # Convert list to set for comparison
    set1_converted_set = set(set1_converted)
    set_gold_converted_set = set(set_gold_converted)

    # Compute the intersection
    intersection = set1_converted_set.intersection(set_gold_converted_set)

    # Find hallucinations (in set1 but not in set_gold)
    hallucinations = set1_converted_set.difference(set_gold_converted_set)

    # Find missing (in set_gold but not in set1)
    missing = set_gold_converted_set.difference(set1_converted_set)

    # Print the intersection
    print("Intersection:")
    for s in intersection:
        print(s)

    # Print hallucinations
    if hallucinations:
        print("\nHallucinations:")
        for hallucination in hallucinations:
            print(hallucination)
    else:
        print("\nNo Hallucinations")

    # Print missing
    if missing:
        print("\nMissing:")
        for miss in missing:
            print(miss)
    else:
        print("\nNo Missing")

    # Print duplicates
    duplicates = [item for item, count in set1_counter.items() if count > 1]
    if duplicates:
        print("\nDuplicates in set1:")
        for duplicate in duplicates:
            print(f"{duplicate} occurs {set1_counter[duplicate]} times")
    else:
        print("\nNo Duplicates in set1")


# Compare sets
set1 = [{"SandyBrown", "Prague", "QR1777", "Yuzu"}]
set_gold = [ {"Pecorino-Romano", "QR1777", "SandyBrown", "Yuzu"},
 {"Pecorino-Romano", "Prague", "QR1777", "SandyBrown"},
 {"Pecorino-Romano", "Prague", "QR1777", "Yuzu"},
 {"Pecorino-Romano", "Platypus", "QR1777", "SandyBrown"},
 {"Pecorino-Romano", "Platypus", "Prague", "QR1777"},
 {"Pecorino-Romano", "Platypus", "QR1777", "Yuzu"},
 {"Prague", "QR1777", "SandyBrown", "Yuzu"},
 {"81", "QR1777", "SandyBrown", "Yuzu"},
 {"81", "Pecorino-Romano", "QR1777", "SandyBrown"},
 {"81", "Pecorino-Romano", "Prague", "QR1777"},
 {"81", "Pecorino-Romano", "QR1777", "Yuzu"},
 {"81", "Pecorino-Romano", "Platypus", "QR1777"},
 {"81", "Prague", "QR1777", "SandyBrown"},
 {"81", "Prague", "QR1777", "Yuzu"},
 {"81", "Platypus", "QR1777", "SandyBrown"},
 {"81", "Platypus", "Prague", "QR1777"},
 {"81", "Platypus", "QR1777", "Yuzu"},
 {"81", "Bossa-Nova", "QR1777", "SandyBrown"},
 {"81", "Bossa-Nova", "Pecorino-Romano", "QR1777"},
 {"81", "Bossa-Nova", "Prague", "QR1777"},
 {"81", "Bossa-Nova", "QR1777", "Yuzu"},
 {"81", "Bossa-Nova", "Platypus", "QR1777"},
 {"Platypus", "QR1777", "SandyBrown", "Yuzu"},
 {"Platypus", "Prague", "QR1777", "SandyBrown"},
 {"Platypus", "Prague", "QR1777", "Yuzu"},
 {"Bossa-Nova", "QR1777", "SandyBrown", "Yuzu"},
 {"Bossa-Nova", "Pecorino-Romano", "QR1777", "SandyBrown"},
 {"Bossa-Nova", "Pecorino-Romano", "Prague", "QR1777"},
 {"Bossa-Nova", "Pecorino-Romano", "QR1777", "Yuzu"},
 {"Bossa-Nova", "Pecorino-Romano", "Platypus", "QR1777"},
 {"Bossa-Nova", "Prague", "QR1777", "SandyBrown"},
 {"Bossa-Nova", "Prague", "QR1777", "Yuzu"},
 {"Bossa-Nova", "Platypus", "QR1777", "SandyBrown"},
 {"Bossa-Nova", "Platypus", "Prague", "QR1777"},
 {"Bossa-Nova", "Platypus", "QR1777", "Yuzu"},
 {"Pecorino-Romano", "Prague", "SandyBrown", "Yuzu"},
 {"Pecorino-Romano", "Platypus", "Prague", "SandyBrown"},
 {"Pecorino-Romano", "Platypus", "SandyBrown", "Yuzu"},
 {"81", "Pecorino-Romano", "Prague", "SandyBrown"},
 {"81", "Pecorino-Romano", "SandyBrown", "Yuzu"},
 {"81", "Pecorino-Romano", "Platypus", "SandyBrown"},
 {"81", "Prague", "SandyBrown", "Yuzu"},
 {"81", "Platypus", "Prague", "SandyBrown"},
 {"81", "Platypus", "SandyBrown", "Yuzu"},
 {"81", "Bossa-Nova", "Pecorino-Romano", "SandyBrown"},
 {"81", "Bossa-Nova", "Prague", "SandyBrown"},
 {"81", "Bossa-Nova", "SandyBrown", "Yuzu"},
 {"81", "Bossa-Nova", "Platypus", "SandyBrown"},
 {"Platypus", "Prague", "SandyBrown", "Yuzu"},
 {"Bossa-Nova", "Pecorino-Romano", "Prague", "SandyBrown"},
 {"Bossa-Nova", "Pecorino-Romano", "SandyBrown", "Yuzu"},
 {"Bossa-Nova", "Pecorino-Romano", "Platypus", "SandyBrown"},
 {"Bossa-Nova", "Prague", "SandyBrown", "Yuzu"},
 {"Bossa-Nova", "Platypus", "Prague", "SandyBrown"},
 {"Bossa-Nova", "Platypus", "SandyBrown", "Yuzu"},
 {"Pecorino-Romano", "Platypus", "Prague", "Yuzu"},
 {"81", "Pecorino-Romano", "Prague", "Yuzu"},
 {"81", "Pecorino-Romano", "Platypus", "Prague"},
 {"81", "Pecorino-Romano", "Platypus", "Yuzu"},
 {"81", "Bossa-Nova", "Pecorino-Romano", "Prague"},
 {"81", "Bossa-Nova", "Pecorino-Romano", "Yuzu"},
 {"81", "Bossa-Nova", "Pecorino-Romano", "Platypus"},
 {"Bossa-Nova", "Pecorino-Romano", "Prague", "Yuzu"},
 {"Bossa-Nova", "Pecorino-Romano", "Platypus", "Prague"},
 {"Bossa-Nova", "Pecorino-Romano", "Platypus", "Yuzu"},
 {"81", "Platypus", "Prague", "Yuzu"},
 {"81", "Bossa-Nova", "Prague", "Yuzu"},
 {"81", "Bossa-Nova", "Platypus", "Prague"},
 {"Bossa-Nova", "Platypus", "Prague", "Yuzu"},
 {"81", "Bossa-Nova", "Platypus", "Yuzu"},]
compare_sets(set1, set_gold)

"""
# Example usage:

# Compare sets
set1 = [{"1", "2", "3"},{"2","3","1"},{"7", "8", "9"}, ]
set_gold = [{"3", "2", "1"}, {"6", "5", "4"}]
compare_sets(set1, set_gold)
"""
# Out:
# Intersection:
# ('Prague', 'QR1777', 'SandyBrown', 'Yuzu')
#
# No Hallucinations
#
# Missing:
# ('81', 'Platypus', 'QR1777', 'SandyBrown')
# ('81', 'Platypus', 'Prague', 'QR1777')
# ('81', 'Bossa-Nova', 'Pecorino-Romano', 'Platypus')
# ('81', 'Prague', 'QR1777', 'Yuzu')
# ('Pecorino-Romano', 'Platypus', 'Prague', 'Yuzu')
# ('Bossa-Nova', 'Platypus', 'Prague', 'QR1777')
# ('81', 'Bossa-Nova', 'Pecorino-Romano', 'Prague')
# ('Pecorino-Romano', 'Prague', 'QR1777', 'Yuzu')
# ('81', 'Pecorino-Romano', 'Prague', 'SandyBrown')
# ('Platypus', 'QR1777', 'SandyBrown', 'Yuzu')
# ('81', 'Prague', 'SandyBrown', 'Yuzu')
# ('81', 'Pecorino-Romano', 'SandyBrown', 'Yuzu')
# ('81', 'Bossa-Nova', 'Platypus', 'QR1777')
# ('81', 'Platypus', 'Prague', 'SandyBrown')
# ('81', 'Platypus', 'QR1777', 'Yuzu')
# ('Bossa-Nova', 'Platypus', 'QR1777', 'Yuzu')
# ('81', 'Bossa-Nova', 'Pecorino-Romano', 'QR1777')
# ('Bossa-Nova', 'Prague', 'QR1777', 'SandyBrown')
# ...

# %% [markdown]
# L5

# %%
# Comparator.py

from collections import Counter


def parse_custom_set(input_list):
    # Convert a list of sets into a list of sorted tuples
    return [tuple(sorted(s)) for s in input_list]


def compare_sets(set1, set_gold):
    # Parse the sets
    set1_converted = parse_custom_set(set1)
    set_gold_converted = parse_custom_set(set_gold)

    # Count the occurrences of each set in set1
    set1_counter = Counter(set1_converted)

    # Convert list to set for comparison
    set1_converted_set = set(set1_converted)
    set_gold_converted_set = set(set_gold_converted)

    # Compute the intersection
    intersection = set1_converted_set.intersection(set_gold_converted_set)

    # Find hallucinations (in set1 but not in set_gold)
    hallucinations = set1_converted_set.difference(set_gold_converted_set)

    # Find missing (in set_gold but not in set1)
    missing = set_gold_converted_set.difference(set1_converted_set)

    # Print the intersection
    print("Intersection:")
    for s in intersection:
        print(s)

    # Print hallucinations
    if hallucinations:
        print("\nHallucinations:")
        for hallucination in hallucinations:
            print(hallucination)
    else:
        print("\nNo Hallucinations")

    # Print missing
    if missing:
        print("\nMissing:")
        for miss in missing:
            print(miss)
    else:
        print("\nNo Missing")

    # Print duplicates
    duplicates = [item for item, count in set1_counter.items() if count > 1]
    if duplicates:
        print("\nDuplicates in set1:")
        for duplicate in duplicates:
            print(f"{duplicate} occurs {set1_counter[duplicate]} times")
    else:
        print("\nNo Duplicates in set1")


# Compare sets
set1 = [
{"SandyBrown","Prague","QR1777","Yuzu","Pecorino-Romano"},
{"SandyBrown","Prague","QR1777","Yuzu","Platypus"},
{"SandyBrown","Prague","QR1777","Yuzu","Bossa-Nova"},
{"SandyBrown","Prague","QR1777","Pecorino-Romano","Platypus"},
{"SandyBrown","Prague","QR1777","Pecorino-Romano","Bossa-Nova"},
{"SandyBrown","Prague","QR1777","Platypus","Bossa-Nova"},
{"SandyBrown","Prague","Yuzu","Pecorino-Romano","Platypus"},
{"SandyBrown","Prague","Yuzu","Pecorino-Romano","Bossa-Nova"},
{"SandyBrown","Prague","Yuzu","Platypus","Bossa-Nova"},
{"SandyBrown","QR1777","Yuzu","Pecorino-Romano","Platypus"},
{"SandyBrown","QR1777","Yuzu","Pecorino-Romano","Bossa-Nova"},
{"SandyBrown","QR1777","Yuzu","Platypus","Bossa-Nova"},
{"Prague","QR1777","Yuzu","Pecorino-Romano","Platypus"},
{"Prague","QR1777","Yuzu","Pecorino-Romano","Bossa-Nova"},
{"Prague","QR1777","Yuzu","Platypus","Bossa-Nova"},
{"QR1777","Yuzu","Pecorino-Romano","Platypus","Bossa-Nova"}]
set_gold = [{"Bossa-Nova","Pecorino-Romano","QR1777","SandyBrown","Yuzu"},
{"Bossa-Nova","Pecorino-Romano","Prague","QR1777","SandyBrown"},
{"Bossa-Nova","Pecorino-Romano","Prague","QR1777","Yuzu"},
{"Bossa-Nova","Pecorino-Romano","Platypus","QR1777","SandyBrown"},
{"Bossa-Nova","Pecorino-Romano","Platypus","Prague","QR1777"},
{"Bossa-Nova","Pecorino-Romano","Platypus","QR1777","Yuzu"},
{"Bossa-Nova","Prague","QR1777","SandyBrown","Yuzu"},
{"Bossa-Nova","Platypus","QR1777","SandyBrown","Yuzu"},
{"Bossa-Nova","Platypus","Prague","QR1777","SandyBrown"},
{"Bossa-Nova","Platypus","Prague","QR1777","Yuzu"},
{"Pecorino-Romano","Platypus","Prague","SandyBrown","Yuzu"},
{"81","Pecorino-Romano","Prague","SandyBrown","Yuzu"},
{"81","Pecorino-Romano","Platypus","Prague","SandyBrown"},
{"81","Pecorino-Romano","Platypus","SandyBrown","Yuzu"},
{"81","Platypus","Prague","SandyBrown","Yuzu"},
{"81","Bossa-Nova","Pecorino-Romano","Prague","SandyBrown"},
{"81","Bossa-Nova","Pecorino-Romano","SandyBrown","Yuzu"},
{"81","Bossa-Nova","Pecorino-Romano","Platypus","SandyBrown"},
{"81","Bossa-Nova","Prague","SandyBrown","Yuzu"},
{"81","Bossa-Nova","Platypus","Prague","SandyBrown"},
{"81","Bossa-Nova","Platypus","SandyBrown","Yuzu"},
{"Bossa-Nova","Pecorino-Romano","Prague","SandyBrown","Yuzu"},
{"Bossa-Nova","Pecorino-Romano","Platypus","Prague","SandyBrown"},
{"Bossa-Nova","Pecorino-Romano","Platypus","SandyBrown","Yuzu"},
{"Bossa-Nova","Platypus","Prague","SandyBrown","Yuzu"},
{"81","Pecorino-Romano","Platypus","Prague","Yuzu"},
{"81","Bossa-Nova","Pecorino-Romano","Prague","Yuzu"},
{"81","Bossa-Nova","Pecorino-Romano","Platypus","Prague"},
{"81","Bossa-Nova","Pecorino-Romano","Platypus","Yuzu"},
{"Bossa-Nova","Pecorino-Romano","Platypus","Prague","Yuzu"},
{"81","Bossa-Nova","Platypus","Prague","Yuzu"}]
compare_sets(set1, set_gold)

"""
# Example usage:

# Compare sets
set1 = [{"1", "2", "3"},{"2","3","1"},{"7", "8", "9"}, ]
set_gold = [{"3", "2", "1"}, {"6", "5", "4"}]
compare_sets(set1, set_gold)
"""
# Out:
# Intersection:
# ('Bossa-Nova', 'Pecorino-Romano', 'Prague', 'QR1777', 'Yuzu')
# ('Bossa-Nova', 'Platypus', 'Prague', 'SandyBrown', 'Yuzu')
# ('Bossa-Nova', 'Platypus', 'Prague', 'QR1777', 'Yuzu')
# ('Pecorino-Romano', 'Platypus', 'Prague', 'SandyBrown', 'Yuzu')
# ('Bossa-Nova', 'Pecorino-Romano', 'QR1777', 'SandyBrown', 'Yuzu')
# ('Bossa-Nova', 'Pecorino-Romano', 'Prague', 'SandyBrown', 'Yuzu')
# ('Bossa-Nova', 'Platypus', 'Prague', 'QR1777', 'SandyBrown')
# ('Bossa-Nova', 'Pecorino-Romano', 'Prague', 'QR1777', 'SandyBrown')
# ('Bossa-Nova', 'Pecorino-Romano', 'Platypus', 'QR1777', 'Yuzu')
# ('Bossa-Nova', 'Prague', 'QR1777', 'SandyBrown', 'Yuzu')
# ('Bossa-Nova', 'Platypus', 'QR1777', 'SandyBrown', 'Yuzu')
#
# Hallucinations:
# ('Pecorino-Romano', 'Platypus', 'QR1777', 'SandyBrown', 'Yuzu')
# ('Pecorino-Romano', 'Prague', 'QR1777', 'SandyBrown', 'Yuzu')
# ('Pecorino-Romano', 'Platypus', 'Prague', 'QR1777', 'SandyBrown')
# ('Pecorino-Romano', 'Platypus', 'Prague', 'QR1777', 'Yuzu')
# ...

# %% [markdown]
# L6

# %%
# Comparator.py

from collections import Counter


def parse_custom_set(input_list):
    # Convert a list of sets into a list of sorted tuples
    return [tuple(sorted(s)) for s in input_list]


def compare_sets(set1, set_gold):
    # Parse the sets
    set1_converted = parse_custom_set(set1)
    set_gold_converted = parse_custom_set(set_gold)

    # Count the occurrences of each set in set1
    set1_counter = Counter(set1_converted)

    # Convert list to set for comparison
    set1_converted_set = set(set1_converted)
    set_gold_converted_set = set(set_gold_converted)

    # Compute the intersection
    intersection = set1_converted_set.intersection(set_gold_converted_set)

    # Find hallucinations (in set1 but not in set_gold)
    hallucinations = set1_converted_set.difference(set_gold_converted_set)

    # Find missing (in set_gold but not in set1)
    missing = set_gold_converted_set.difference(set1_converted_set)

    # Print the intersection
    print("Intersection:")
    for s in intersection:
        print(s)

    # Print hallucinations
    if hallucinations:
        print("\nHallucinations:")
        for hallucination in hallucinations:
            print(hallucination)
    else:
        print("\nNo Hallucinations")

    # Print missing
    if missing:
        print("\nMissing:")
        for miss in missing:
            print(miss)
    else:
        print("\nNo Missing")

    # Print duplicates
    duplicates = [item for item, count in set1_counter.items() if count > 1]
    if duplicates:
        print("\nDuplicates in set1:")
        for duplicate in duplicates:
            print(f"{duplicate} occurs {set1_counter[duplicate]} times")
    else:
        print("\nNo Duplicates in set1")


# Compare sets
set1 = [{"SandyBrown","Prague","QR1777","Yuzu","Pecorino-Romano","Platypus"},
{"Prague","QR1777","Yuzu","Pecorino-Romano","Platypus","Bossa-Nova"},
{"SandyBrown","QR1777","Yuzu","Pecorino-Romano","Platypus","Bossa-Nova"},
{"SandyBrown","Prague","Yuzu","Pecorino-Romano","Platypus","Bossa-Nova"},
{"SandyBrown","Prague","QR1777","Pecorino-Romano","Platypus","Bossa-Nova"},
{"SandyBrown","Prague","QR1777","Yuzu","Platypus","Bossa-Nova"},
{"SandyBrown","Prague","QR1777","Yuzu","Pecorino-Romano","Bossa-Nova"}]
set_gold = [{"Pecorino-Romano","Platypus","Prague","QR1777","SandyBrown","Yuzu"},
{"81","Pecorino-Romano","Prague","QR1777","SandyBrown","Yuzu"},
{"81","Pecorino-Romano","Platypus","QR1777","SandyBrown","Yuzu"},
{"81","Pecorino-Romano","Platypus","Prague","QR1777","SandyBrown"},
{"81","Pecorino-Romano","Platypus","Prague","QR1777","Yuzu"},
{"81","Platypus","Prague","QR1777","SandyBrown","Yuzu"},
{"81","Bossa-Nova","Pecorino-Romano","QR1777","SandyBrown","Yuzu"},
{"81","Bossa-Nova","Pecorino-Romano","Prague","QR1777","SandyBrown"},
{"81","Bossa-Nova","Pecorino-Romano","Prague","QR1777","Yuzu"},
{"81","Bossa-Nova","Pecorino-Romano","Platypus","QR1777","SandyBrown"},
{"81","Bossa-Nova","Pecorino-Romano","Platypus","Prague","QR1777"},
{"81","Bossa-Nova","Pecorino-Romano","Platypus","QR1777","Yuzu"},
{"81","Bossa-Nova","Prague","QR1777","SandyBrown","Yuzu"},
{"81","Bossa-Nova","Platypus","QR1777","SandyBrown","Yuzu"},
{"81","Bossa-Nova","Platypus","Prague","QR1777","SandyBrown"},
{"81","Bossa-Nova","Platypus","Prague","QR1777","Yuzu"},
{"Bossa-Nova","Pecorino-Romano","Prague","QR1777","SandyBrown","Yuzu"},
{"Bossa-Nova","Pecorino-Romano","Platypus","QR1777","SandyBrown","Yuzu"},
{"Bossa-Nova","Pecorino-Romano","Platypus","Prague","QR1777","SandyBrown"},
{"Bossa-Nova","Pecorino-Romano","Platypus","Prague","QR1777","Yuzu"},
{"Bossa-Nova","Platypus","Prague","QR1777","SandyBrown","Yuzu"},
{"81","Pecorino-Romano","Platypus","Prague","SandyBrown","Yuzu"},
{"81","Bossa-Nova","Pecorino-Romano","Prague","SandyBrown","Yuzu"},
{"81","Bossa-Nova","Pecorino-Romano","Platypus","Prague","SandyBrown"},
{"81","Bossa-Nova","Pecorino-Romano","Platypus","SandyBrown","Yuzu"},
{"81","Bossa-Nova","Platypus","Prague","SandyBrown","Yuzu"},
{"Bossa-Nova","Pecorino-Romano","Platypus","Prague","SandyBrown","Yuzu"},
{"81","Bossa-Nova","Pecorino-Romano","Platypus","Prague","Yuzu"},]
compare_sets(set1, set_gold)

"""
# Example usage:

# Compare sets
set1 = [{"1", "2", "3"},{"2","3","1"},{"7", "8", "9"}, ]
set_gold = [{"3", "2", "1"}, {"6", "5", "4"}]
compare_sets(set1, set_gold)
"""
# Out:
# Intersection:
# ('Bossa-Nova', 'Pecorino-Romano', 'Platypus', 'Prague', 'QR1777', 'Yuzu')
# ('Bossa-Nova', 'Pecorino-Romano', 'Platypus', 'QR1777', 'SandyBrown', 'Yuzu')
# ('Bossa-Nova', 'Pecorino-Romano', 'Platypus', 'Prague', 'QR1777', 'SandyBrown')
# ('Bossa-Nova', 'Platypus', 'Prague', 'QR1777', 'SandyBrown', 'Yuzu')
# ('Bossa-Nova', 'Pecorino-Romano', 'Platypus', 'Prague', 'SandyBrown', 'Yuzu')
# ('Bossa-Nova', 'Pecorino-Romano', 'Prague', 'QR1777', 'SandyBrown', 'Yuzu')
# ('Pecorino-Romano', 'Platypus', 'Prague', 'QR1777', 'SandyBrown', 'Yuzu')
#
# No Hallucinations
#
# Missing:
# ('81', 'Bossa-Nova', 'Pecorino-Romano', 'Platypus', 'Prague', 'SandyBrown')
# ('81', 'Bossa-Nova', 'Prague', 'QR1777', 'SandyBrown', 'Yuzu')
# ('81', 'Bossa-Nova', 'Platypus', 'Prague', 'QR1777', 'Yuzu')
# ('81', 'Bossa-Nova', 'Pecorino-Romano', 'Platypus', 'QR1777', 'Yuzu')
# ('81', 'Bossa-Nova', 'Pecorino-Romano', 'Platypus', 'SandyBrown', 'Yuzu')
# ...

# %% [markdown]
# L7

# %%
# Comparator.py

from collections import Counter


def parse_custom_set(input_list):
    # Convert a list of sets into a list of sorted tuples
    return [tuple(sorted(s)) for s in input_list]


def compare_sets(set1, set_gold):
    # Parse the sets
    set1_converted = parse_custom_set(set1)
    set_gold_converted = parse_custom_set(set_gold)

    # Count the occurrences of each set in set1
    set1_counter = Counter(set1_converted)

    # Convert list to set for comparison
    set1_converted_set = set(set1_converted)
    set_gold_converted_set = set(set_gold_converted)

    # Compute the intersection
    intersection = set1_converted_set.intersection(set_gold_converted_set)

    # Find hallucinations (in set1 but not in set_gold)
    hallucinations = set1_converted_set.difference(set_gold_converted_set)

    # Find missing (in set_gold but not in set1)
    missing = set_gold_converted_set.difference(set1_converted_set)

    # Print the intersection
    print("Intersection:")
    for s in intersection:
        print(s)

    # Print hallucinations
    if hallucinations:
        print("\nHallucinations:")
        for hallucination in hallucinations:
            print(hallucination)
    else:
        print("\nNo Hallucinations")

    # Print missing
    if missing:
        print("\nMissing:")
        for miss in missing:
            print(miss)
    else:
        print("\nNo Missing")

    # Print duplicates
    duplicates = [item for item, count in set1_counter.items() if count > 1]
    if duplicates:
        print("\nDuplicates in set1:")
        for duplicate in duplicates:
            print(f"{duplicate} occurs {set1_counter[duplicate]} times")
    else:
        print("\nNo Duplicates in set1")


# Compare sets
set1 = [{"SandyBrown", "Prague", "QR1777", "Yuzu", "Pecorino-Romano", "Platypus", "Bossa-Nova"}]
set_gold = [{"81","Pecorino-Romano","Platypus","Prague","QR1777","SandyBrown","Yuzu"},
{"81","Bossa-Nova","Pecorino-Romano","Prague","QR1777","SandyBrown","Yuzu"},
{"81","Bossa-Nova","Pecorino-Romano","Platypus","QR1777","SandyBrown","Yuzu"},
{"81","Bossa-Nova","Pecorino-Romano","Platypus","Prague","QR1777","SandyBrown"},
{"81","Bossa-Nova","Pecorino-Romano","Platypus","Prague","QR1777","Yuzu"},
{"81","Bossa-Nova","Platypus","Prague","QR1777","SandyBrown","Yuzu"},
{"Bossa-Nova","Pecorino-Romano","Platypus","Prague","QR1777","SandyBrown","Yuzu"},
{"81","Bossa-Nova","Pecorino-Romano","Platypus","Prague","SandyBrown","Yuzu"},]
compare_sets(set1, set_gold)

"""
# Example usage:

# Compare sets
set1 = [{"1", "2", "3"},{"2","3","1"},{"7", "8", "9"}, ]
set_gold = [{"3", "2", "1"}, {"6", "5", "4"}]
compare_sets(set1, set_gold)
"""
# Out:
# Intersection:
# ('Bossa-Nova', 'Pecorino-Romano', 'Platypus', 'Prague', 'QR1777', 'SandyBrown', 'Yuzu')
#
# No Hallucinations
#
# Missing:
# ('81', 'Bossa-Nova', 'Platypus', 'Prague', 'QR1777', 'SandyBrown', 'Yuzu')
# ('81', 'Bossa-Nova', 'Pecorino-Romano', 'Platypus', 'Prague', 'SandyBrown', 'Yuzu')
# ('81', 'Bossa-Nova', 'Pecorino-Romano', 'Platypus', 'Prague', 'QR1777', 'SandyBrown')
# ('81', 'Bossa-Nova', 'Pecorino-Romano', 'Platypus', 'QR1777', 'SandyBrown', 'Yuzu')
# ('81', 'Pecorino-Romano', 'Platypus', 'Prague', 'QR1777', 'SandyBrown', 'Yuzu')
# ('81', 'Bossa-Nova', 'Pecorino-Romano', 'Platypus', 'Prague', 'QR1777', 'Yuzu')
# ('81', 'Bossa-Nova', 'Pecorino-Romano', 'Prague', 'QR1777', 'SandyBrown', 'Yuzu')
#
# No Duplicates in set1
# '\n# Example usage:\n\n# Compare sets\nset1 = [{"1", "2", "3"},{"2","3","1"},{"7", "8", "9"}, ]\nset_gold = [{"3", "2", "1"}, {"6", "5", "4"}]\ncompare_sets(set1, set_gold)\n'

# %% [markdown]
# L8

# %%
# Comparator.py

from collections import Counter


def parse_custom_set(input_list):
    # Convert a list of sets into a list of sorted tuples
    return [tuple(sorted(s)) for s in input_list]


def compare_sets(set1, set_gold):
    # Parse the sets
    set1_converted = parse_custom_set(set1)
    set_gold_converted = parse_custom_set(set_gold)

    # Count the occurrences of each set in set1
    set1_counter = Counter(set1_converted)

    # Convert list to set for comparison
    set1_converted_set = set(set1_converted)
    set_gold_converted_set = set(set_gold_converted)

    # Compute the intersection
    intersection = set1_converted_set.intersection(set_gold_converted_set)

    # Find hallucinations (in set1 but not in set_gold)
    hallucinations = set1_converted_set.difference(set_gold_converted_set)

    # Find missing (in set_gold but not in set1)
    missing = set_gold_converted_set.difference(set1_converted_set)

    # Print the intersection
    print("Intersection:")
    for s in intersection:
        print(s)

    # Print hallucinations
    if hallucinations:
        print("\nHallucinations:")
        for hallucination in hallucinations:
            print(hallucination)
    else:
        print("\nNo Hallucinations")

    # Print missing
    if missing:
        print("\nMissing:")
        for miss in missing:
            print(miss)
    else:
        print("\nNo Missing")

    # Print duplicates
    duplicates = [item for item, count in set1_counter.items() if count > 1]
    if duplicates:
        print("\nDuplicates in set1:")
        for duplicate in duplicates:
            print(f"{duplicate} occurs {set1_counter[duplicate]} times")
    else:
        print("\nNo Duplicates in set1")


# Compare sets
set1 = [{"SandyBrown", "Prague", "QR1777", "Yuzu", "81", "Pecorino-Romano", "Platypus", "Bossa-Nova"}]
set_gold = [{"81","Bossa-Nova","Pecorino-Romano","Platypus","Prague","QR1777","SandyBrown","Yuzu"}]
compare_sets(set1, set_gold)

"""
# Example usage:

# Compare sets
set1 = [{"1", "2", "3"},{"2","3","1"},{"7", "8", "9"}, ]
set_gold = [{"3", "2", "1"}, {"6", "5", "4"}]
compare_sets(set1, set_gold)
"""
# Out:
# Intersection:
# ('81', 'Bossa-Nova', 'Pecorino-Romano', 'Platypus', 'Prague', 'QR1777', 'SandyBrown', 'Yuzu')
#
# No Hallucinations
#
# No Missing
#
# No Duplicates in set1
# '\n# Example usage:\n\n# Compare sets\nset1 = [{"1", "2", "3"},{"2","3","1"},{"7", "8", "9"}, ]\nset_gold = [{"3", "2", "1"}, {"6", "5", "4"}]\ncompare_sets(set1, set_gold)\n'
