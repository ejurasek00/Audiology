# %% [markdown]
# # Length 1 | Support 5
# ## Gold
# {"1"},
# {"Gold"},
# {"QR1777"},
# {"SandyBrown"},
# {"Berlin"},
# {"Prague"},
# {"Yuzu"},
# {"81"}
# ## GPT-5
# {"SandyBrown"},
# {"Gold"},
# {"Prague"},
# {"Berlin"},
# {"QR1777"},
# {"Yuzu"},
# {"81"}
# ## Claude Sonet 4
# {"SandyBrown"},
# {"Gold"},
# {"Prague"},
# {"Berlin"},
# {"QR1777"},
# {"Yuzu"},
# {"1"},
# {"81"}
# ## Gemini 2.5 Flash
# {"Prague"},
# {"QR1777"},
# {"Yuzu"},
# {"SandyBrown"},
# {"Gold"},
# {"81"}
# ## Perplexity
# {"Gold"},
# {"SandyBrown"},
# {"Prague"},
# {"QR1777"},
# {"Yuzu"},
# {"81"}
# ## LLAMA 3.1-405b-instruct
# {"QR1777"},
# {"Yuzu"}
# ## LLAMA-3.3-70b-instruct
# {"SandyBrown"},
# {"Prague"},
# {"Yuzu"}
# ## Mixtral-8x7b-instruct-v0.1
# {"SandyBrown"},
# {"Prague"},
# {"QR1777"},
# {"Yuzu"}

# %% [markdown]
# # Length 2 | Support 5
# ## Gold
# {"QR1777", "SandyBrown"},
# {"Prague", "QR1777"},
# {"QR1777", "Yuzu"},
# {"81", "QR1777"},
# {"Prague", "SandyBrown"},
# {"SandyBrown", "Yuzu"},
# {"81", "SandyBrown"},
# {"Prague", "Yuzu"},
# {"81", "Prague"},
# {"81", "Yuzu"}
# ## GPT-5
# {"SandyBrown","Prague"},{"SandyBrown","QR1777"},{"SandyBrown","Yuzu"},{"SandyBrown","81"},
# {"Prague","QR1777"},{"Prague","Yuzu"},{"Prague","81"},
# {"QR1777","Yuzu"},{"QR1777","81"},{"Yuzu","81"}
# ## Claude Sonet 4
# {"SandyBrown","Prague"},
# {"SandyBrown","QR1777"},
# {"SandyBrown","Yuzu"},
# {"SandyBrown","81"},
# {"Prague","QR1777"},
# {"Prague","Yuzu"},
# {"Prague","81"},
# {"QR1777","Yuzu"},
# {"QR1777","81"},
# {"Yuzu","81"}
# ## Gemini 2.5 Flash
# {"Prague","QR1777"},
# {"Prague","Yuzu"},
# {"Prague","SandyBrown"},
# {"Prague","81"},
# {"QR1777","Yuzu"},
# {"QR1777","SandyBrown"},
# {"QR1777","81"},
# {"Yuzu","SandyBrown"},
# {"Yuzu","81"},
# {"SandyBrown","81"}
# ## Perplexity
# {"SandyBrown","Prague"},
# {"SandyBrown","QR1777"},
# {"SandyBrown","Yuzu"},
# {"SandyBrown","81"},
# {"Prague","QR1777"},
# {"Prague","Yuzu"},
# {"Prague","81"},
# {"QR1777","Yuzu"},
# {"QR1777","81"},
# {"Yuzu","81"}
# ## LLAMA 3.1-405b-instruct
# {"Prague","QR1777"},
# {"Prague","Yuzu"},
# {"QR1777","Yuzu"}
# ## LLAMA-3.3-70b-instruct
# {"SandyBrown","Prague"},
# {"SandyBrown","Yuzu"},
# {"Prague","Yuzu"},
# {"QR1777","Yuzu"}
# ## Mixtral-8x7b-instruct-v0.1
# {"SandyBrown","Prague"},
# {"SandyBrown","QR1777"},
# {"SandyBrown","Yuzu"},
# {"Prague","Yuzu"},
# {"QR1777","Yuzu"}

# %% [markdown]
# # Length 3 | Support 5
# ## Gold
# {"QR1777", "SandyBrown", "Yuzu"},
# {"Prague", "QR1777", "SandyBrown"},
# {"Prague", "QR1777", "Yuzu"},
# {"81", "QR1777", "SandyBrown"},
# {"81", "Prague", "QR1777"},
# {"81", "QR1777", "Yuzu"},
# {"Prague", "SandyBrown", "Yuzu"},
# {"81", "Prague", "SandyBrown"},
# {"81", "SandyBrown", "Yuzu"},
# {"81", "Prague", "Yuzu"}
# ## GPT-5
# {"SandyBrown","Prague","QR1777"},{"SandyBrown","Prague","Yuzu"},{"SandyBrown","Prague","81"},
# {"SandyBrown","QR1777","Yuzu"},{"SandyBrown","QR1777","81"},{"SandyBrown","Yuzu","81"},
# {"Prague","QR1777","Yuzu"},{"Prague","QR1777","81"},{"Prague","Yuzu","81"},
# {"QR1777","Yuzu","81"}
# ## Claude Sonet 4
# {"SandyBrown","Prague","QR1777"},
# {"SandyBrown","Prague","Yuzu"},
# {"SandyBrown","Prague","81"},
# {"SandyBrown","QR1777","Yuzu"},
# {"SandyBrown","QR1777","81"},
# {"SandyBrown","Yuzu","81"},
# {"Prague","QR1777","Yuzu"},
# {"Prague","QR1777","81"},
# {"Prague","Yuzu","81"},
# {"QR1777","Yuzu","81"}
# ## Gemini 2.5 Flash
# {"Prague","QR1777","Yuzu"},
# {"Prague","QR1777","SandyBrown"},
# {"Prague","QR1777","81"},
# {"Prague","Yuzu","SandyBrown"},
# {"Prague","Yuzu","81"},
# {"Prague","SandyBrown","81"},
# {"QR1777","Yuzu","SandyBrown"},
# {"QR1777","Yuzu","81"},
# {"QR1777","SandyBrown","81"},
# {"Yuzu","SandyBrown","81"}
# ## Perplexity
# {"SandyBrown","Prague","QR1777"},
# {"SandyBrown","Prague","Yuzu"},
# {"SandyBrown","Prague","81"},
# {"SandyBrown","QR1777","Yuzu"},
# {"SandyBrown","QR1777","81"},
# {"SandyBrown","Yuzu","81"},
# {"Prague","QR1777","Yuzu"},
# {"Prague","QR1777","81"},
# {"Prague","Yuzu","81"},
# {"QR1777","Yuzu","81"}
# ## LLAMA 3.1-405b-instruct
# {"SandyBrown","Prague","QR1777"},
# {"SandyBrown","Prague","Yuzu"},
# {"Prague","QR1777","Yuzu"}
# ## LLAMA-3.3-70b-instruct
# {"SandyBrown","Prague","Yuzu"},
# {"SandyBrown","QR1777","Yuzu"},
# {"Prague","QR1777","Yuzu"}
# ## Mixtral-8x7b-instruct-v0.1
# {}

# %% [markdown]
# # Length 4 | Support 5
# ## Gold
# {"Prague", "QR1777", "SandyBrown", "Yuzu"},
# {"81", "QR1777", "SandyBrown", "Yuzu"},
# {"81", "Prague", "QR1777", "SandyBrown"},
# {"81", "Prague", "QR1777", "Yuzu"},
# {"81", "Prague", "SandyBrown", "Yuzu"}
# ## GPT-5
# {"SandyBrown","Prague","QR1777","Yuzu"},
# {"SandyBrown","Prague","QR1777","81"},
# {"SandyBrown","Prague","Yuzu","81"},
# {"SandyBrown","QR1777","Yuzu","81"},
# {"Prague","QR1777","Yuzu","81"}
# ## Claude Sonet 4
# {"SandyBrown","Prague","QR1777","Yuzu"},
# {"SandyBrown","Prague","QR1777","81"},
# {"SandyBrown","Prague","Yuzu","81"},
# {"SandyBrown","QR1777","Yuzu","81"},
# {"Prague","QR1777","Yuzu","81"}
# ## Gemini 2.5 Flash
# {"Prague","QR1777","Yuzu","SandyBrown"},
# {"Prague","QR1777","Yuzu","81"},
# {"Prague","QR1777","SandyBrown","81"},
# {"Prague","Yuzu","SandyBrown","81"},
# {"QR1777","Yuzu","SandyBrown","81"}
# ## Perplexity
# {"SandyBrown","Prague","QR1777","Yuzu"},
# {"SandyBrown","Prague","QR1777","81"},
# {"SandyBrown","Prague","Yuzu","81"},
# {"SandyBrown","QR1777","Yuzu","81"},
# {"Prague","QR1777","Yuzu","81"}
# ## LLAMA 3.1-405b-instruct
# {"SandyBrown","Prague","QR1777","Yuzu"}
# ## LLAMA-3.3-70b-instruct
# {"SandyBrown","Prague","QR1777","Yuzu"}
# ## Mixtral-8x7b-instruct-v0.1
# {}

# %% [markdown]
# # Length 5 | Support 5
# ## Gold
# {"81", "Prague", "QR1777", "SandyBrown", "Yuzu"}
# ## GPT-5
# {"SandyBrown","Prague","QR1777","Yuzu","81"}
# ## Claude Sonet 4
# {"SandyBrown","Prague","QR1777","Yuzu","81"}
# ## Gemini 2.5 Flash
# {"Prague","QR1777","Yuzu","SandyBrown","81"}
# ## Perplexity
# {"SandyBrown","Prague","QR1777","Yuzu","81"}
# ## LLAMA 3.1-405b-instruct
# {"SandyBrown","Prague","QR1777","Yuzu","81"}
# ## LLAMA-3.3-70b-instruct
# {"SandyBrown","Prague","QR1777","Yuzu","81"}
# ## Mixtral-8x7b-instruct-v0.1
# {}
